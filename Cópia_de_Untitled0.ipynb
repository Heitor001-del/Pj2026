# %% [markdown]
# <a href="https://colab.research.google.com/github/Heitor001-del/Pj2026/blob/main/C%C3%B3pia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Heitor")
print("Dias")
print("machado")
# Out:
# Heitor
# Dias
# machado

# %%
nome = "Heitor"
idade = 19

print(nome)
print(idade)
# Out:
# Heitor
# 19

# %%
nome = input("Qual seu nome? ")
print("Olá,", nome)
# Out:
# Qual seu nome? Heitor Dias Machado
# Olá, Heitor Dias Machado

# %%
for i in range(20):
  print("Python")
# Out:
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python

# %%
def saudacao():
  print("Olá")
  print("Seja Bem-Vindo")
saudacao()
# Out:
# Olá
# Seja Bem-Vindo

# %%
for i in range(5):

  saudacao()
# Out:
# Olá
# Seja Bem-Vindo
# Olá
# Seja Bem-Vindo
# Olá
# Seja Bem-Vindo
# Olá
# Seja Bem-Vindo
# Olá
# Seja Bem-Vindo

# %%
nome = input("Media Do Aluno")

nota1 = float(input("digite a nota 1:"))
nota2 = float(input("digite a nota 2:"))
nota3 = float(input("digite a nota 3:"))
nota4 = float(input("digita a nota 4:"))

media = (nota1 + nota2 + nota3 + nota4) / 4

print("Aluno:", nome)
print("Media:", media)

if media >= 6:
  print("Aprovado")
else:
  print("Reprovado")
# Out:
# Media Do Aluno Heitor
# digite a nota 1:5
# digite a nota 2:4
# digite a nota 3:9
# digita a nota 4:6
# Aluno:  Heitor
# Media: 8.0
# Aprovado
