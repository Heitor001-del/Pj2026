# %% [markdown]
# <a href="https://colab.research.google.com/github/Heitor001-del/Pj2026/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Passo 1 - Definir a classe Livro
class Livro:
    def __init__(self, titulo, autor, genero, quantidade):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.quantidade = quantidade

    def __str__(self):
        return f"Título: {self.titulo} | Autor: {self.autor} | Gênero: {self.genero} | Quantidade: {self.quantidade}"

        # Passo 2 - Criar a lista de livros
livros = []


# Passo 3 - Função para cadastrar um novo livro
def cadastrar_livro():
    print("\n===== CADASTRAR LIVRO ===telek=")

    titulo = input("Digite o título: ")
    autor = input("Digite o autor: ")
    genero = input("Digite o gênero: ")
    quantidade = int(input("Digite a quantidade disponível: "))

    livro = Livro(titulo, autor, genero, quantidade)
    livros.append(livro)

    print("Livro cadastrado com sucesso!")


# Função para listar todos os livros
def listar_livros():
    print("\n===== LIVROS CADASTRADOS ===telek=")

    if len(livros) == 0:
        print("Nenhum livro cadastrado.")
    else:
        for livro in livros:
            print(livro)



 # Função para buscar um livro pelo título
def buscar_livro():
    print("\n===== BUSCAR LIVRO ===telek=")

    titulo_busca = input("Digite o título do livro: ")

    encontrado = False

    for livro in livros:
        if livro.titulo.lower() == titulo_busca.lower():
            print("\nLivro encontrado:")
            print(livro)
            encontrado = True
            break

    if not encontrado:
        print("Livro não encontrado.")



# Passo 4 - Gerar gráfico de quantidade de livros por gênero
def gerar_grafico():
    if len(livros) == 0:
        print("Não há livros cadastrados para gerar o gráfico.")
        return

    generos = {}

    for livro in livros:
        if livro.genero in generos:
            generos[livro.genero] += livro.quantidade
        else:
            generos[livro.genero] = livro.quantidade

    plt.bar(generos.keys(), generos.values())

    plt.title("Quantidade de Livros por Gênero")
    plt.xlabel("Gênero")
    plt.ylabel("Quantidade de Livros")

    plt.show()



# Passo 5 - Menu principal para testar o sistema
def menu():
    while True:
        print("\n===== BIBLIOTECA ===telek=")
        print("1 - Cadastrar livro")
        print("2 - Listar livros")
        print("3 - Buscar livro")
        print("4 - Gerar gráfico")
        print("5 - Excluir livro") # Adicionando a opção de excluir
        print("6 - Sair")

        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            cadastrar_livro()

        elif opcao == "2":
            listar_livros()

        elif opcao == "3":
            buscar_livro()

        elif opcao == "4":
            gerar_grafico()

        elif opcao == "5": # Tratando a nova opção
            excluir_livro()

        elif opcao == "6":
            print("Sistema encerrado.")
            break

        else:
            print("Opção inválida. Tente novamente.")
menu()
# Out:
# ===== BIBLIOTECA ===telek=
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Excluir livro
# 6 - Sair
# Escolha uma opção: 1
#
# ===== CADASTRAR LIVRO ===telek=
# Digite o título: percy jackson
# Digite o autor: alexandre de moraes
# Digite o gênero: masculino
# Digite a quantidade disponível: 499
# Livro cadastrado com sucesso!
#
# ===== BIBLIOTECA ===telek=
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Excluir livro
# 6 - Sair
# Escolha uma opção: 2
#
# ===== LIVROS CADASTRADOS ===telek=
# Título: percy jackson | Autor: alexandre de moraes | Gênero: masculino | Quantidade: 499
#
# ===== BIBLIOTECA ===telek=
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Excluir livro
# 6 - Sair
